# %% [markdown]
# # Hotel Reservations Support Vector Classifier
# This notebook contains the steps to train and evaluate a Support Vector Classifier on the Hotel Reservations dataset.

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import pandas as pd

# Initialize and train the Support Vector Classifier (SVC) with standard scaling
svc_classifier = make_pipeline(StandardScaler(), SVC(random_state=42))
svc_classifier.fit(X_train, y_train)

# Predict on the test set
y_pred_svc = svc_classifier.predict(X_test)

# Evaluate the model
accuracy_svc = accuracy_score(y_test, y_pred_svc)
classification_rep_svc = classification_report(y_test, y_pred_svc)

accuracy_svc, classification_rep_svc
